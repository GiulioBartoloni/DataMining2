# %% [markdown]
# # Module 1 — Outlier Detection
#
# ## Dataset: Child Mind Institute — Problematic Internet Use
#
# ---

# %% [markdown]
# ## Step 00: Setup & Load

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA 
from isotree import IsolationForest

# %%
df = pd.read_csv("../../processed_data/cmi_preprocessed.csv", index_col='id')

# PCIAT_Total is excluded from outlier detection — it is the source of `sii`
# and is reserved for the regression task downstream.
df = df.drop(columns=["PCIAT-PCIAT_Total"], errors="ignore")

print(f"Shape: {df.shape}")
df.head()
# Out:
# Shape: (8259, 19)
#     Basic_Demos-Age  Basic_Demos-Sex  CGAS-CGAS_Score  Physical-Height  \
# id
# 0               5.0                0        51.000000       116.840000
# 1               9.0                0        57.666667       121.920000
# 2              10.0                1        71.000000       143.510000
# 3               9.0                0        71.000000       142.240000
# 4              18.0                1        65.000000       138.853333
#
#     Physical-Weight  Physical-HeartRate  BIA-BIA_Activity_Level_num  \
# id
# 0         23.042474           89.833333                         2.0
# 1         20.865232           70.000000                         2.0
# 2         34.291555           94.000000                         3.0
# 3         37.013107           97.000000                         3.0
# 4         34.926584           73.833333                         3.0
#
#     BIA-BIA_BMI  BIA-BIA_DEE  BIA-BIA_FFM  BIA-BIA_FFMI  BIA-BIA_FMI  \
# id
# 0       16.8792      1492.00      41.5862       13.8177      3.06143
# 1       14.0371      1498.65      42.0291       12.8254      1.21172
# 2       17.9665      1863.98      61.0662       14.0925      3.69863
# 3       18.2943      1923.44      62.7757       14.0740      4.22033
# 4       17.9665      1863.98      61.0662       14.0925      3.69863
#
#     BIA-BIA_Frame_num  PreInt_EduHx-computerinternet_hoursday  sii  \
# id
# 0                 1.0                                     3.0  2.0
# 1                 1.0                                     0.0  0.0
# 2                 2.0                                     2.0  0.0
# 3                 2.0                                     0.0  1.0
# 4                 2.0                                     1.0  0.0
#
#     Physical-Mean_arterial_pressure    BIA-FM  FGC-Fitness_score  PAQ_Combined
# id
# 0                         84.222222  2.123081                  3      2.258333
# 1                         90.666667  0.828527                  4      2.175000
# 2                         82.333333  5.546522                  5      2.090000
# 3                         79.000000  6.967458                  4      2.230500
# 4                         83.333333  5.649235                  5      1.565000

# %% [markdown]
# ---
# ## Step 01: Extended Isolation Forest

# %%
# Fit Extended Isolation Forest (ndim = n_features for fully extended hyperplane splits)
eif = IsolationForest(
    ndim=df.shape[1],
    ntrees=500,
    sample_size=256,
    random_seed=42,
    nthreads=-1,
)
eif.fit(df)
# Out:
# /home/giulio/Uni/Master/DataMining2/.venv/lib/python3.14/site-packages/isotree/__init__.py:1737: UserWarning: Instantiating CategoricalDtype without any arguments.Pass a CategoricalDtype instance to silence this warning.
#   X_cat = X.select_dtypes(include = [pd.CategoricalDtype, "object", "bool"])
# /home/giulio/Uni/Master/DataMining2/.venv/lib/python3.14/site-packages/isotree/__init__.py:1757: UserWarning: Instantiating CategoricalDtype without any arguments.Pass a CategoricalDtype instance to silence this warning.
#   self.cols_categ_    = X.select_dtypes(include = [pd.CategoricalDtype, "object", "bool"]).columns.to_numpy(copy=True)
# /home/giulio/Uni/Master/DataMining2/.venv/lib/python3.14/site-packages/sklearn/externals/_numpydoc/docscrape.py:420: UserWarning: Unknown section Note
#   self[section] = content
# IsolationForest(ndim=19, random_seed=42, sample_size=256)

# %%
# Compute anomaly scores (higher = more anomalous)
scores = eif.predict(df, output="score")

# Identify top 1% outliers
threshold = np.percentile(scores, 99)
outlier_mask = scores >= threshold

n_outliers = outlier_mask.sum()
print(f"Anomaly score threshold (99th percentile): {threshold:.4f}")
print(f"Number of outliers (top 1%): {n_outliers} / {len(df)} ({n_outliers/len(df)*100:.2f}%)")
# Out:
# Anomaly score threshold (99th percentile): 0.6107
# Number of outliers (top 1%): 83 / 8259 (1.00%)

# %%
# Score distribution
fig, ax = plt.subplots(figsize=(10, 4))
ax.hist(scores, bins=80, edgecolor="white", alpha=0.7)
ax.axvline(threshold, color="red", linestyle="--", label=f"99th percentile = {threshold:.3f}")
ax.set_xlabel("Anomaly Score")
ax.set_ylabel("Frequency")
ax.set_title("Extended Isolation Forest — Anomaly Score Distribution")
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Step 02: Outlier Visualization via PCA
#
# Project the data onto the first two principal components and highlight the detected outliers.

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df)

# PCA (3 components for both 2D and 3D plots)
pca = PCA(n_components=2, random_state=42)
X_pca = pca.fit_transform(X_scaled)

ev = pca.explained_variance_ratio_
print(f"Explained variance — PC1: {ev[0]:.2%}, PC2: {ev[1]:.2%}")
print(f"Cumulative (2 PCs): {ev.sum():.2%}")
# Out:
# Explained variance — PC1: 25.61%, PC2: 7.18%
# Cumulative (2 PCs): 32.79%

# %%
# 2D scatter plot (PC1 vs PC2)
fig, ax = plt.subplots(figsize=(10, 7))

inliers = ~outlier_mask
ax.scatter(X_pca[inliers, 0], X_pca[inliers, 1],
           c="steelblue", s=8, alpha=0.3, label="Inliers")
ax.scatter(X_pca[outlier_mask, 0], X_pca[outlier_mask, 1],
           c="red", s=30, alpha=0.8, edgecolors="darkred", linewidths=0.5,
           label=f"Outliers (top 1%, n={n_outliers})")

ax.set_xlabel(f"PC1 ({ev[0]:.1%} variance)")
ax.set_ylabel(f"PC2 ({ev[1]:.1%} variance)")
ax.set_title("Extended Isolation Forest — Outliers on PCA (2D)")
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Step 03: Outlier Profile
#
# Inspect which features drive the detected outliers by comparing their statistics to the overall dataset.

# %%
# Compare mean of outliers vs. inliers (in standardized z-score terms)
df_outliers = df[outlier_mask]
df_inliers = df[~outlier_mask]

comparison = pd.DataFrame({
    "Mean (all)": df.mean(),
    "Mean (outliers)": df_outliers.mean(),
    "Mean (inliers)": df_inliers.mean(),
    "Std (all)": df.std(),
})
comparison["Z-diff"] = (comparison["Mean (outliers)"] - comparison["Mean (all)"]) / comparison["Std (all)"]
comparison.sort_values("Z-diff", key=abs, ascending=False)
# Out:
#                                          Mean (all)  Mean (outliers)  \
# BIA-BIA_FFMI                              14.824049        38.656699
# BIA-BIA_FFM                               75.167575      1043.219977
# BIA-BIA_DEE                             1932.091955      9335.798395
# BIA-FM                                     9.560215        33.952668
# BIA-BIA_BMI                               18.827165        24.908965
# BIA-BIA_FMI                                4.617404         8.898522
# Physical-Weight                           38.331373        62.321719
# Physical-Height                          145.003444       167.107620
# Basic_Demos-Age                           10.226178        12.891566
# Physical-Mean_arterial_pressure           84.413986        90.576975
# BIA-BIA_Frame_num                          1.751302         2.084337
# sii                                        0.442305         0.710843
# PreInt_EduHx-computerinternet_hoursday     0.958833         1.325301
# CGAS-CGAS_Score                           65.509666        62.520080
# FGC-Fitness_score                          4.724422         4.325301
# PAQ_Combined                               2.342262         2.433857
# Basic_Demos-Sex                            0.401622         0.277108
# Physical-HeartRate                        81.846450        80.931727
# BIA-BIA_Activity_Level_num                 2.761472         2.710843
#
#                                         Mean (inliers)    Std (all)    Z-diff
# BIA-BIA_FFMI                                 14.582108     5.340652  4.462498
# BIA-BIA_FFM                                  65.340233   224.317272  4.315550
# BIA-BIA_DEE                                1856.932020  2393.926008  3.092705
# BIA-FM                                        9.312591    11.277906  2.162853
# BIA-BIA_BMI                                  18.765425     3.544720  1.715735
# BIA-BIA_FMI                                   4.573944     2.872300  1.490484
# Physical-Weight                              38.087831    16.861680  1.422773
# Physical-Height                             144.779049    18.164655  1.216878
# Basic_Demos-Age                              10.199119     3.556817  0.749375
# Physical-Mean_arterial_pressure              84.351422    10.014889  0.615383
# BIA-BIA_Frame_num                             1.747921     0.545260  0.610783
# sii                                           0.439579     0.729217  0.368255
# PreInt_EduHx-computerinternet_hoursday        0.955113     1.032647  0.354882
# CGAS-CGAS_Score                              65.540015     8.914570 -0.335360
# FGC-Fitness_score                             4.728474     1.390240 -0.287088
# PAQ_Combined                                  2.341332     0.350018  0.261687
# Basic_Demos-Sex                               0.402886     0.490256 -0.253978
# Physical-HeartRate                           81.855736    10.946923 -0.083560
# BIA-BIA_Activity_Level_num                    2.761986     0.739511 -0.068463

# %% [markdown]
# ---
# ## Step 04: Export Datasets

# %%
# Dataset with anomaly scores and outlier flag
df_scored = df.copy()
df_scored["anomaly_score"] = scores
df_scored["is_outlier"] = outlier_mask.astype(int)
df_scored.to_csv("../../outlier_data/eif.csv")
print(f"Scored dataset: {df_scored.shape}")
df_scored
# Out:
# Scored dataset: (8259, 21)
#       Basic_Demos-Age  Basic_Demos-Sex  CGAS-CGAS_Score  Physical-Height  \
# id
# 0                 5.0                0        51.000000       116.840000
# 1                 9.0                0        57.666667       121.920000
# 2                10.0                1        71.000000       143.510000
# 3                 9.0                0        71.000000       142.240000
# 4                18.0                1        65.000000       138.853333
# ...               ...              ...              ...              ...
# 8454             16.0                1        62.666667       178.714400
# 8455              7.0                1        66.000000       117.017800
# 8456             10.0                1        69.500000       142.570200
# 8458             15.0                1        55.500000       162.026600
# 8459              7.0                0        61.500000       130.708400
#
#       Physical-Weight  Physical-HeartRate  BIA-BIA_Activity_Level_num  \
# id
# 0           23.042474           89.833333                         2.0
# 1           20.865232           70.000000                         2.0
# 2           34.291555           94.000000                         3.0
# 3           37.013107           97.000000                         3.0
# 4           34.926584           73.833333                         3.0
# ...               ...                 ...                         ...
# 8454        65.271889           64.166667                         4.0
# 8455        22.226008           82.500000                         1.0
# 8456        21.681698           80.500000                         3.0
# 8458        45.132404           87.500000                         2.0
# 8459        19.821970           80.500000                         3.0
#
#       BIA-BIA_BMI  BIA-BIA_DEE  BIA-BIA_FFM  ...  BIA-BIA_FMI  \
# id                                           ...
# 0       16.879200  1492.000000    41.586200  ...     3.061430
# 1       14.037100  1498.650000    42.029100  ...     1.211720
# 2       17.966500  1863.980000    61.066200  ...     3.698630
# 3       18.294300  1923.440000    62.775700  ...     4.220330
# 4       17.966500  1863.980000    61.066200  ...     3.698630
# ...           ...          ...          ...  ...          ...
# 8454    23.853830  2827.366295   115.712153  ...     5.254770
# 8455    14.813292  1490.847845    42.546078  ...     1.094562
# 8456    15.627678  1678.330810    49.863069  ...     2.644989
# 8458    19.665279  1674.735823    80.716700  ...     5.881968
# 8459    15.691061  1073.450000    42.190726  ...     2.463184
#
#       BIA-BIA_Frame_num  PreInt_EduHx-computerinternet_hoursday  sii  \
# id
# 0                   1.0                                     3.0  2.0
# 1                   1.0                                     0.0  0.0
# 2                   2.0                                     2.0  0.0
# 3                   2.0                                     0.0  1.0
# 4                   2.0                                     1.0  0.0
# ...                 ...                                     ...  ...
# 8454                2.0                                     2.0  0.0
# 8455                1.0                                     0.0  0.0
# 8456                1.0                                     0.0  1.0
# 8458                2.0                                     1.0  2.0
# 8459                1.0                                     0.0  0.0
#
#       Physical-Mean_arterial_pressure     BIA-FM  FGC-Fitness_score  \
# id
# 0                           84.222222   2.123081                  3
# 1                           90.666667   0.828527                  4
# 2                           82.333333   5.546522                  5
# 3                           79.000000   6.967458                  4
# 4                           83.333333   5.649235                  5
# ...                               ...        ...                ...
# 8454                        82.833333  24.553407                  6
# 8455                        73.500000   0.705448                  6
# 8456                        79.833333   1.658913                  3
# 8458                        85.111111  12.058771                  5
# 8459                        79.277778   1.246665                  4
#
#       PAQ_Combined  anomaly_score  is_outlier
# id
# 0         2.258333       0.452459           0
# 1         2.175000       0.410976           0
# 2         2.090000       0.370618           0
# 3         2.230500       0.372369           0
# 4         1.565000       0.402401           0
# ...            ...            ...         ...
# 8454      2.835000       0.472982           0
# 8455      2.500000       0.425211           0
# 8456      2.500000       0.390123           0
# 8458      2.000000       0.412716           0
# 8459      2.693333       0.394122           0
#
# [8259 rows x 21 columns]
